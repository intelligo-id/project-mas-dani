# %%
from google.colab import drive
drive.mount ('/content/drive')

import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

import seaborn as sns
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ***Tanpa datetime***

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/masdani/concat_data_6item - concat_data_6item.csv')
df #tanpa datetime
# Out:
#                         Marktleistung  Verrechnungsbetrag  Periode  year
# 0      Arbeitsplatz Software Schale 2                42.0  2018.01  2018
# 1      Arbeitsplatz Software Schale 2              5432.0  2018.01  2018
# 2      Arbeitsplatz Software Schale 2              1197.0  2018.01  2018
# 3      Arbeitsplatz Software Schale 2              2925.0  2018.01  2018
# 4      Arbeitsplatz Software Schale 2                 0.0  2018.01  2018
# ...                               ...                 ...      ...   ...
# 80845  Arbeitsplatz Software Schale 3                 0.0  2021.09  2021
# 80846  Arbeitsplatz Software Schale 3                 0.0  2021.09  2021
# 80847  Arbeitsplatz Software Schale 3               513.0  2021.09  2021
# 80848              Software Schale 3a               290.0  2021.09  2021
# 80849                        Internet                28.0  2021.09  2021
#
# [80850 rows x 4 columns]

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Periode', y='Verrechnungsbetrag', data=df, hue='Marktleistung')
plt.legend(bbox_to_anchor=(1.5, 1), loc='upper left')
plt.xticks(rotation=100)
plt.title('Diagram Time series 2018-2021')
plt.show()

# %% [markdown]
# ***Pakai datetime***

# %%
df_new=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/masdani/manipulasi_concat_data_6item.csv')
df_new #pakai datetime
# Out:
#                         Marktleistung  Verrechnungsbetrag  ...  year  Unnamed: 4
# 0      Arbeitsplatz Software Schale 2                42.0  ...  2018         NaN
# 1      Arbeitsplatz Software Schale 2              5432.0  ...  2018         NaN
# 2      Arbeitsplatz Software Schale 2              1197.0  ...  2018         NaN
# 3      Arbeitsplatz Software Schale 2              2925.0  ...  2018         NaN
# 4      Arbeitsplatz Software Schale 2                 0.0  ...  2018         NaN
# ...                               ...                 ...  ...   ...         ...
# 80845  Arbeitsplatz Software Schale 3                 0.0  ...  2021         NaN
# 80846  Arbeitsplatz Software Schale 3                 0.0  ...  2021         NaN
# 80847  Arbeitsplatz Software Schale 3               513.0  ...  2021         NaN
# 80848              Software Schale 3a               290.0  ...  2021         NaN
# 80849                        Internet                28.0  ...  2021         NaN
#
# ...

# %%
import datetime

#df_new['year'] = pd.DatetimeIndex(df_new['year']).year

# # # from datetime import datetime
#df_new['year']=pd.to_datetime(df_new['year'], format='%Y')
#df_new['Periode']=pd.to_datetime(df_new['Periode'], format='%Y')
# # import time
# # df= df_new["year"]
# # df_new=time.strftime(df,"%Y")

# import pandas as pd
# import datetime
# import period
#df_new["year"]=pd.to_datetime(df_new["year"], format='%Y%m%d', errors='ignore')
df_new["Periode"]=pd.to_datetime(df_new["Periode"], format='%Y%m%d', errors='ignore')

# %%
df_new
# Out:
#                         Marktleistung  Verrechnungsbetrag  ...  year  Unnamed: 4
# 0      Arbeitsplatz Software Schale 2                42.0  ...  2018         NaN
# 1      Arbeitsplatz Software Schale 2              5432.0  ...  2018         NaN
# 2      Arbeitsplatz Software Schale 2              1197.0  ...  2018         NaN
# 3      Arbeitsplatz Software Schale 2              2925.0  ...  2018         NaN
# 4      Arbeitsplatz Software Schale 2                 0.0  ...  2018         NaN
# ...                               ...                 ...  ...   ...         ...
# 80845  Arbeitsplatz Software Schale 3                 0.0  ...  2021         NaN
# 80846  Arbeitsplatz Software Schale 3                 0.0  ...  2021         NaN
# 80847  Arbeitsplatz Software Schale 3               513.0  ...  2021         NaN
# 80848              Software Schale 3a               290.0  ...  2021         NaN
# 80849                        Internet                28.0  ...  2021         NaN
#
# ...

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Periode', y='Verrechnungsbetrag', data=df_new, hue='Marktleistung')
plt.legend(bbox_to_anchor=(1.5, 1), loc='upper left')
plt.xticks(rotation=100)
plt.title('Diagrm Diagram Time series 2018-2021')
plt.show()
